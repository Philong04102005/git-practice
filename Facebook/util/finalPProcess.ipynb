# %%
import pandas as pd

# %%
# status_false = pd.read_csv("../data/account/status_false.csv")
status_true = pd.read_csv("../data/account/status_true.csv")

# %%
# status = pd.concat([status_true, status_false])
# status
# Out:
#       acc_id                      username                      password  \
# 0   acc_0077   phamxuandepgai789@gmail.com                      thuc2001
# 1   acc_0076   Thienlamgreyrat42@gmail.com                  Thienlam2704
# 2   acc_0098            chupp794@gmail.com                   123phuong@@
# 3   acc_0018  sonyeuchaunhieulam@gmail.com  sonyeuchaunhieulam0123456789
# 4   acc_0095      TuanNHuy260705@gmail.com           b0BFx%w=P^~NJWzjy.r
# ..       ...                           ...                           ...
# 40  acc_0086           votai9338@gmail.com                   Zacc147193@
# 41  acc_0093        hanuehanue69@gmail.com                  hanuehanue@@
# 42  acc_0094            anhp2465@gmail.com                      thuc2001
# 43  acc_0099         minhbui1573@gmail.com                  minhbui1234@
# 44  acc_0112           nhntjun05@gmail.com                  Thienlam2704
#
#                 name  status  TotalFriends
# 0         Thanh Kiều    True         704.0
# ...

# %%
status_true = status[status["status"] == True].reset_index(drop=True)
status_true
# Out:
#       acc_id                      username                      password  \
# 0   acc_0077   phamxuandepgai789@gmail.com                      thuc2001
# 1   acc_0076   Thienlamgreyrat42@gmail.com                  Thienlam2704
# 2   acc_0098            chupp794@gmail.com                   123phuong@@
# 3   acc_0018  sonyeuchaunhieulam@gmail.com  sonyeuchaunhieulam0123456789
# 4   acc_0095      TuanNHuy260705@gmail.com           b0BFx%w=P^~NJWzjy.r
# ..       ...                           ...                           ...
# 58  acc_0038   phonghuynh8888666@gmail.com                  Thienlam2704
# 59  acc_0039        pnam78012355@gmail.com                  Thienlam2704
# 60  acc_0040           nhain3056@gmail.com                  Thienlam2704
# 61  acc_0084           nhntjun04@gmail.com                Thanhtrung123@
# 62  acc_0094            anhp2465@gmail.com                      thuc2001
#
#                 name  status  TotalFriends
# 0         Thanh Kiều    True         704.0
# ...

# %%
status_false = status[status["status"] == False].reset_index(drop=True)
status_false
# Out:
#       acc_id                       username            password  \
# 0   acc_0061    thienlamgreyrat47@gmail.com        Thienlam2704
# 1   acc_0069    thienlamgreyrat12@gmail.com        Thienlam2704
# 2   acc_0068  laclan7846gjr7eglfw@gmail.com         rinrin4568@
# 3   acc_0060    thienlamgreyrat46@gmail.com        Thienlam2704
# 4   acc_0002         pnam78012354@gmail.com           Net2price
# 5   acc_0003       truongdiem8272@gmail.com           Net2price
# 6   acc_0004         pnam78012356@gmail.com           Net2price
# 7   acc_0005           thinhlac41@gmail.com           Net2price
# 8   acc_0006       phungthinh2606@gmail.com           Net2price
# 9   acc_0007            vmac03697@gmail.com           Net2price
# 10  acc_0008       chilamxinhvaio@gmail.com      helluworld123@
# 11  acc_0009         baonghiem338@gmail.com           Net2price
# 12  acc_0010    6doanhnghieptre@gmail.com\n  guiembonghongdalat
# 13  acc_0011       gumball85520@gmail.com\n     chucmungemnha\n
# ...

# %%
# status_true.to_csv("../data/account/status_true.csv", index=False)
# status_false.to_csv("../data/account/status_false.csv", index=False)

# %%
n = len(status_true) // 2  # lấy nửa độ dài
status_true_1 = status_true.iloc[:n].reset_index(drop=True)
status_true_2 = status_true.iloc[n:].reset_index(drop=True)

# %%
status_true_1.to_csv("../data/account/status_true_1.csv", index=False)
status_true_2.to_csv("../data/account/status_true_2.csv", index=False)
