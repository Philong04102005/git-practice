# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_xml("sitemap.xml",  parser='etree')
df
# Out:
#                                                      loc  \
# 0                                https://www.revoland.vn
# 1                    https://www.revoland.vn/landingpage
# 2                   https://www.revoland.vn/appointments
# 3                     https://www.revoland.vn/comparison
# 4                         https://www.revoland.vn/myrevo
# ...                                                  ...
# 10011  https://www.revoland.vn/properties/68b940b1045...
# 10012  https://www.revoland.vn/properties/68ba6ab5036...
# 10013  https://www.revoland.vn/properties/68be5dcd135...
# 10014  https://www.revoland.vn/properties/68c63e31b85...
# 10015  https://www.revoland.vn/properties/68d2b12d072...
#
#                         lastmod changefreq  priority
# 0      2025-10-14T10:12:40.016Z      daily       1.0
# 1      2025-10-14T10:12:40.016Z     weekly       0.9
# 2      2025-10-14T10:12:40.016Z     weekly       0.7
# 3      2025-10-14T10:12:40.016Z     weekly       0.6
# ...

# %%
df[df["loc"].str.contains("/properties")].to_csv("./linkpost.csv", index=False)
